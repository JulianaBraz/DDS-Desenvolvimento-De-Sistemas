# %% [markdown]
# ![Captura de tela 2025-09-02 023608.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023626.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023644.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023704.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023723.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023749.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023812.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023834.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-02 023911.png](data:image/png;base64,...)
